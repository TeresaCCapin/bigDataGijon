# %%
# pip install pandas # para instalar la librería de pandas

# %%
import pandas as pd #son los alias para no tener que escribir siempre 'pandas'
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# IMPORTAR ARCHIVO CSV -  LEER UN ARCHIVO
df = pd.read_csv('')#entre comillas la ruta donde esta guardada el archivo. Aquí - en el colab de google - tenemos que subir el archivo. Hay que guardarlo en una variable (df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f6fcfd97ac17> in <cell line: 2>()
#       1 # IMPORTAR ARCHIVO CSV -  LEER UN ARCHIVO
# ----> 2 df = pd.read_csv('')#entre comillas la ruta donde esta guardada el archivo. Aquí - en el colab de google - tenemos que subir el archivo. Hay que guardarlo en una variable (df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
# EXPORTAR UN ARCHIVO CSV . GUARDAR
#nombre_variable_datos.to_csv('resultado_prueba.csv')
df.to_csv('resultado_prueba.csv')

# %% [markdown]
# # Ejercicio 1
#
# Obtener las primeras `3` filas de un objeto `DataFrame`.

# %%
#Datos
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución, aquí tu respuesta
#df['nombre']# así podemos seleccionar una columna. Para seleccionar 2 hay que crear listas
# lista = ['nombre', 'califico']
# df[lista]

df.head(3)
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí

# %% [markdown]
# # Ejercicio 2
#
# Obtener las últimas `3` filas de un objeto `DataFrame`.

# %%
#Datos
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución
df.tail(3)
# Out:
#    nombre  puntaje  intentos califico
# h   Edgar      NaN         1       No
# i   Angie      8.0         2       No
# j  Irlesa     18.0         1       Sí

# %% [markdown]
# # Ejercicio 3
#
# Seleccionar las columnas ['nombre', 'califico'] de un objeto `DataFrame`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución
df.loc[:,['nombre', 'califico']]
# Out:
#     nombre califico
# a    Oliva       Sí
# b  Daniela       No
# c     Juan       Sí
# d   Germán       No
# e   Edward       No
# f     Alex       Sí
# g    Julio       Sí
# h    Edgar       No
# i    Angie       No
# j   Irlesa       Sí

# %% [markdown]
# # Ejercicio 4
#
# Comprobar si este objeto `DataFrame` está vacío con `empty`.

# %%
df = pd.DataFrame({'X': []})

df
# Out:
# Empty DataFrame
# Columns: [X]
# Index: []

# %%
#Solución
if df.empty == True:
  print('Está vacío')
else:
  print('Esta lleno')
# Out:
# Está vacío

# %% [markdown]
# # Ejercicio 5
#
# Crear un objeto `DataFrame` a partir de objetos `Series`.

# %%
#Partimos de dos series
nombres = pd.Series(['Edward', 'Germán', 'Daniela'])
edades = pd.Series([27, 23, 19])

# %%
#Solución #Todas las columnas deben de tener el mismo número de elementos
#1. Metemos las series en un diccionario
diccionario = {'Mombre': nombres, 'Edad': edades}
#2. Metemos el diccionario dentro de un dataframe
pd.DataFrame(diccionario) #D y F en DataFrame en maýusculas. Delante pd. para llamar a la librería de pandas
# Out:
#     Mombre  Edad
# 0   Edward    27
# 1   Germán    23
# 2  Daniela    19

# %% [markdown]
# # Ejercicio 6
#
# Determinar los datos en un `DataFrame` que son nulos (NaN).

# %%
nombres = ['Edward', 'Daniela', 'Germán']
edades = [5, 6, np.nan]
fecha_nacimiento = [pd.Timestamp('1990-01-03'), None, np.nan]

personas = {'nombre': nombres, 'edad': edades, 'fecha_nacimiento': fecha_nacimiento}

df = pd.DataFrame(data=personas)

df
# Out:
#     nombre  edad fecha_nacimiento
# 0   Edward   5.0       1990-01-03
# 1  Daniela   6.0              NaT
# 2   Germán   NaN              NaT

# %%
#Solución
df.isnull()
# Out:
#    nombre   edad  fecha_nacimiento
# 0   False  False             False
# 1   False  False              True
# 2   False   True              True

# %% [markdown]
# # Ejercicio 7
#
# Modificar un valor o entrada específico de un objeto `DataFrame` usando `loc`.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df
# Out:
#    X  Y   Z
# a  1  5   2
# b  2  4   3
# c  3  3   5
# d  4  2   7
# e  5  1  11

# %%
#Solución
df.loc['d':'e', 'Y':'Z']=[[33, 14],[2, 55]]

df
# Out:
#    X  Y   Z
# a  1  5   2
# b  2  4   3
# c  3  3   5
# d  4  2   7
# e  5  1  11

# %% [markdown]
# # Ejercicio 8
#
# Acceder a un valor o entrada específico de un objeto `DataFrame` usando `loc`.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df
# Out:
#    X  Y   Z
# a  1  5   2
# b  2  4   3
# c  3  3   5
# d  4  2   7
# e  5  1  11

# %%
#Solución
df.loc['a']
# Out:
# X    1
# Y    5
# Z    2
# Name: a, dtype: int64

# %% [markdown]
# # Ejercicio 9
#
# Sumar los valores de la columna intentos con `sum`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución
suma_intentos=df['intentos'].sum()
print('La suma de la columna intentos es: ', suma_intentos)
# Out:
# La suma de la columna intentos es:  19

# %% [markdown]
# # Ejercicio 10 (Opcional)
#
#  Agregar una nueva fila a un objeto `DataFrame` por medio de `loc`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df

# %%
#Solución

# %% [markdown]
# # Ejercicio 11
#
# Eliminar una fila de un `DataFrame` con la función `drop`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df

# %%
#Solución

# %% [markdown]
# # Ejercicio 12
#
# Mostrar los n primeros y últimos registros de un objeto `DataFrame` con `head` y `tail`.

# %%
datos_1 = list(range(1, 101))
datos_2 = list(range(1, 101))

df = pd.DataFrame({'A': datos_1, 'B': datos_2})

df
# Out:
#       A    B
# 0     1    1
# 1     2    2
# 2     3    3
# 3     4    4
# 4     5    5
# ..  ...  ...
# 95   96   96
# 96   97   97
# 97   98   98
# 98   99   99
# 99  100  100
#
# [100 rows x 2 columns]

# %%
#Solución

# %% [markdown]
# # Ejercicio 13
#
# Agregar una nueva columna a un `DataFrame` con notación de slicing.
#
# `df['nombre_nueva_columna'] = valores`

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df

# %%
#Valores nueva columna
colores = ['Negro', 'Blanco', 'Azul', 'Verde', 'Rojo', 'Amarillo',
           'Gris', 'Naranja', 'Lila', 'Café']
#Solución

# %% [markdown]
# # Recorrer un df
#
#  Para iterar cada una de las filas de un `DataFrame` utilizamos la función `iterrows`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#TAREA HECHA
for indice, fila in df.iterrows():
    print(fila['nombre'], fila['califico'])
# Out:
# Oliva Sí
# Daniela No
# Juan Sí
# Germán No
# Edward No
# Alex Sí
# Julio Sí
# Edgar No
# Angie No
# Irlesa Sí

# %% [markdown]
# # Ejercicio 14 (Opcional)
#
# Obtener como una lista Python los nombres de las columnas de un `DataFrame`.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

df = pd.DataFrame(datos)

df

# %%
#Solución

# %% [markdown]
# # Ejercicio 15
#
# Renombrar las columnas de un objeto `DataFrame` a partir del diccionario dado.

# %%
datos = {'Columna1': [1, 2, 3, 4, 5], 'Columna2': [5, 4, 3, 2, 1],
         'Columna3': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df

# %%
#Diccionario con los nuevos nombres de las columnas
renombrado_columnas = {'Columna1': 'X', 'Columna2': 'Y', 'Columna3': 'Z'}

# %% [markdown]
# # Ejercicio 16
#
# * Guardar los registros de un `DataFrame` en un archivo de formato **CSV**.
# * Prueba a descargarlos en tu PC.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí
